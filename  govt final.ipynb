# %% [markdown]
# 2211CS010571(GROUP3-37)

# %% [markdown]
# SREEJA UPLANCHIWAR

# %% [markdown]
# GOVT DATASET-TEMP_ANNUAL_SEASONAL_MEAN govt.csv

# %% [markdown]
# Introduction
# Annual and seasonal mean temperature analysis is essential for understanding climate trends and their broader impact on the environment, agriculture, public health, and disaster preparedness. The annual mean temperature represents the average temperature recorded over a year, offering insights into long-term climatic shifts, while the seasonal mean temperature focuses on specific seasons, helping to identify patterns such as warming trends in summer or extreme cold events in winter. Analyzing these temperature variations is crucial in assessing the effects of climate change, predicting weather anomalies, and formulating policies for sustainable development. Rising temperatures can influence agricultural productivity, alter ecosystems, and increase the frequency of extreme weather events like heatwaves and droughts. Additionally, temperature fluctuations have direct implications for public health, as extreme conditions can lead to heat stress or cold-related illnesses. By studying annual and seasonal temperature data, researchers and policymakers can make informed decisions to mitigate climate risks, improve urban planning, and develop strategies for a sustainable and resilient future.

# %%
import pandas as pd
import warnings as warnings
warnings.filterwarnings("ignore")
df=pd.read_csv("TEMP_ANNUAL_SEASONAL_MEAN govt.csv")
df
# Out:
#        YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0    1901.0   25.42    20.11    27.64    28.16     23.1
# 1    1902.0   25.42    20.88    27.96    27.98    22.51
# 2    1903.0   25.01    19.99    27.02       28    22.33
# 3    1904.0   24.93    19.76    27.23    27.57    22.56
# 4    1905.0   24.84    18.36    26.38     28.2    23.13
# ..      ...     ...      ...      ...      ...      ...
# 118  2019.0   25.86    20.71       28     28.6    23.49
# 119  2020.0   25.78    20.79    27.58    28.45    23.75
# 120  2021.0   25.93    21.43    27.97    28.36    23.66
# 121     NaN     NaN      NaN      NaN      NaN      NaN
# 122     NaN  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
#
# [123 rows x 6 columns]

# %% [markdown]
# df["ANNUAL"] = pd.to_numeric(df["ANNUAL"], errors='coerce').fillna(0).astype(int)
# df["JAN-FEB"] = pd.to_numeric(df["JAN-FEB"], errors='coerce').fillna(0).astype(int)
# df["MAR-MAY"] = pd.to_numeric(df["MAR-MAY"], errors='coerce').fillna(0).astype(int)
# df["JUN-SEP"] = pd.to_numeric(df["JUN-SEP"], errors='coerce').fillna(0).astype(int)
# df["OCT-DEC"] = pd.to_numeric(df["OCT-DEC"], errors='coerce').fillna(0).astype(int)
# df["YEAR"] = pd.to_numeric(df["YEAR"], errors='coerce').fillna(0).astype(int)

# %%
cols = ["YEAR", "ANNUAL", "JAN-FEB", "MAR-MAY", "JUN-SEP", "OCT-DEC"]
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df.fillna(df.mean(), inplace=True)
df = df.round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     123 non-null    float64
#  1   ANNUAL   123 non-null    float64
#  2   JAN-FEB  123 non-null    float64
#  3   MAR-MAY  123 non-null    float64
#  4   JUN-SEP  123 non-null    float64
#  5   OCT-DEC  123 non-null    float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
df.head()
# Out:
#      YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  1901.0   25.42    20.11    27.64    28.16    23.10
# 1  1902.0   25.42    20.88    27.96    27.98    22.51
# 2  1903.0   25.01    19.99    27.02    28.00    22.33
# 3  1904.0   24.93    19.76    27.23    27.57    22.56
# 4  1905.0   24.84    18.36    26.38    28.20    23.13

# %% [markdown]
# Data cleaning

# %%
df.isnull().sum()
# Out:
# YEAR       0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     123 non-null    float64
#  1   ANNUAL   123 non-null    float64
#  2   JAN-FEB  123 non-null    float64
#  3   MAR-MAY  123 non-null    float64
#  4   JUN-SEP  123 non-null    float64
#  5   OCT-DEC  123 non-null    float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
df["YEAR"] = df["YEAR"].fillna(df["YEAR"].mean())
df["ANNUAL"] = df["ANNUAL"].fillna(df["ANNUAL"].mean())
df["JAN-FEB"] = df["JAN-FEB"].fillna(df["JAN-FEB"].mean())
df["MAR-MAY"] = df["MAR-MAY"].fillna(df["MAR-MAY"].mean())
df["JUN-SEP"] = df["JUN-SEP"].fillna(df["JUN-SEP"].mean())
df["OCT-DEC"] = df["OCT-DEC"].fillna(df["OCT-DEC"].mean())

# %%
df.isnull().sum()
# Out:
# YEAR       0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
df["YEAR"] = pd.to_numeric(df["YEAR"], errors='coerce')  
df = df.dropna(subset=["YEAR"])  
df["YEAR"] = df["YEAR"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     123 non-null    int32
#  1   ANNUAL   123 non-null    float64
#  2   JAN-FEB  123 non-null    float64
#  3   MAR-MAY  123 non-null    float64
#  4   JUN-SEP  123 non-null    float64
#  5   OCT-DEC  123 non-null    float64
# dtypes: float64(5), int32(1)
# memory usage: 5.4 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df["YEAR"] = (df["YEAR"] // 10) * 10  

plt.figure(figsize=(12, 5))
sns.lineplot(x=df["YEAR"], y=df["ANNUAL"], marker="o", color="b", linewidth=2)
plt.title("Annual Temperature Trend (1901-2021)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.xticks(range(df["YEAR"].min(), df["YEAR"].max(), 100))
plt.show()

# %%
# plot_trend(df["YEAR"], df["ANNUAL"], "Annual Temperature Trend (1901-2021)", "Temperature (°C)")

# %% [markdown]
# The plot shows annual temperature trends from 1901 to 2021, highlighting gradual warming and climate change effects.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
for season in df.columns[1:]:  # Automatically select all seasonal columns
    sns.lineplot(x=df["YEAR"], y=df[season], label=season)

plt.title("Seasonal Temperature Trends (1901-2021)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# The plot displays seasonal temperature trends from 1901 to 2021, showing variations and long-term warming patterns.

# %%
# df["ANNUAL_5Y_MA"] = df["ANNUAL"].rolling(window=5).mean()
# plot_trend(df["YEAR"], df["ANNUAL_5Y_MA"], "5-Year Moving Average of Annual Temperature", "Temperature (°C)")

# %% [markdown]
# The plot illustrates the 5-year moving average of annual temperatures, smoothing fluctuations to reveal long-term trends.

# %%
print("Hottest Year:", df.loc[df["ANNUAL"].idxmax(), ["YEAR", "ANNUAL"]])
print("Coldest Year:", df.loc[df["ANNUAL"].idxmin(), ["YEAR", "ANNUAL"]])
# Out:
# Hottest Year: YEAR      2010.0
# ANNUAL      26.2
# Name: 115, dtype: float64
# Coldest Year: YEAR      1910.00
# ANNUAL      24.54
# Name: 16, dtype: float64

# %% [markdown]
# The code finds the hottest and coldest years by identifying the maximum and minimum annual temperatures in the dataset.

# %%
temperature_columns = ["ANNUAL", "JAN-FEB", "MAR-MAY", "JUN-SEP", "OCT-DEC"]
plt.figure(figsize=(10, 6))
sns.histplot(data=df[temperature_columns[1:]])
plt.title("Seasonal Temperature Distribution (1901-2021)", fontsize=14)
plt.xlabel("Season", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.show()

# %% [markdown]
# The plot visualizes seasonal temperature distributions from 1901 to 2021, highlighting variations and frequency across seasons.

# %%
df["DECADE"] = (df["YEAR"] // 10) * 10
decadal_avg = df.groupby("DECADE")["ANNUAL"].mean()
plt.figure(figsize=(12, 5))
sns.barplot(x=decadal_avg.index.astype(str), y=decadal_avg.values, palette="viridis")
plt.title("Decadal Average Temperature (1901-2021)", fontsize=14)
plt.xlabel("Decade", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The plot showcases decadal average temperatures from 1901 to 2021, revealing long-term warming trends across decades.

# %%
# df["TEMP_CHANGE"] = df["ANNUAL"].diff()
# plot_trend(df["YEAR"], df["TEMP_CHANGE"], "Year-to-Year Temperature Change", "Temperature Change (°C)")

# %% [markdown]
# The plot highlights year-to-year temperature changes, showing fluctuations and potential climate variability over time.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[temperature_columns].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Seasonal Temperatures", fontsize=14)
plt.show()

# %% [markdown]
# The plot displays the correlation matrix of seasonal temperatures, revealing relationships and trends among different seasons.

# %%
Q1 = df["ANNUAL"].quantile(0.25)
Q3 = df["ANNUAL"].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR
print("Extreme Warm Years:", df[df["ANNUAL"] > upper_bound][["YEAR", "ANNUAL"]])
print("Extreme Cold Years:", df[df["ANNUAL"] < lower_bound][["YEAR", "ANNUAL"]])
# Out:
# Extreme Warm Years: Empty DataFrame
# Columns: [YEAR, ANNUAL]
# Index: []
# Extreme Cold Years: Empty DataFrame
# Columns: [YEAR, ANNUAL]
# Index: []

# %% [markdown]
# The code identifies extreme warm and cold years using the IQR method, detecting outliers beyond 1.5 times the interquartile range.

# %%
df["ANNUAL"].plot(kind="hist", bins=30, edgecolor="black", alpha=0.7, figsize=(10,5))
plt.title("Distribution of Annual Temperatures")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The plot represents the distribution of annual temperatures, showing frequency variations and potential climate change patterns.

# %%
plt.figure(figsize=(10, 5))
for season in temperature_columns[1:]:
    sns.kdeplot(df[season], label=season, fill=True)
plt.title("Kernel Density Estimate of Seasonal Temperatures")
plt.xlabel("Temperature (°C)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# The plot visualizes seasonal temperature distributions using Kernel Density Estimation, highlighting variations and overlapping trends.

# %%
hottest_decade = df.groupby("DECADE")["ANNUAL"].mean()
hottest_decade.plot(kind="pie", autopct="%1.1f%%", figsize=(8,8), colormap="coolwarm")
plt.title("Proportion of Hottest Decades")
plt.ylabel("")
plt.show()

# %% [markdown]
# The plot illustrates the proportion of average temperatures across decades, highlighting the hottest periods over time.

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df[temperature_columns[1:]])
plt.title("Violin Plot of Seasonal Temperatures")
plt.xlabel("Season")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot visualizes seasonal temperature distributions, showing density, variability, and potential outliers across different seasons.

# %%
sns.scatterplot(x=df["ANNUAL"], y=df["MAR-MAY"], alpha=0.5)
plt.title("Annual vs. Summer Temperatures")
plt.xlabel("Annual Temperature (°C)")
plt.ylabel("Summer Temperature (°C)")
plt.show()

# %% [markdown]
# The plot shows the relationship between annual and summer temperatures, highlighting trends and potential correlations.

# %%
df.groupby("DECADE")[temperature_columns[1:]].mean().plot(kind="bar", stacked=True, figsize=(10, 6))
plt.title("Stacked Bar Chart of Seasonal Temperature Averages by Decade")
plt.xlabel("Decade")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot presents seasonal temperature averages per decade, highlighting variations and long-term warming trends across seasons.

# %%
sns.lineplot(x=df["YEAR"], y=df["ANNUAL"], ci=95)
plt.title("Annual Temperature Trend with Confidence Intervals")
plt.xlabel("Year")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot illustrates the annual temperature trend with a 95% confidence interval, highlighting variability and trends.

# %%
df[temperature_columns[1:]].mean().plot(kind="bar", figsize=(8, 5), color="green")
plt.title("Average Seasonal Temperatures")
plt.xlabel("Season")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot displays average seasonal temperatures, highlighting variations across different seasons over the recorded period.

# %%
sns.rugplot(df["ANNUAL"], height=0.1, color="red")
plt.title("Rug Plot of Annual Temperature Distribution")
plt.xlabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot visualizes the distribution of annual temperatures using a rug plot, showing individual data point density.

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(data=df[temperature_columns[1:]], alpha=0.6)
plt.title("Swarm Plot of Seasonal Temperatures")
plt.xlabel("Season")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot visualizes seasonal temperature distributions using a swarm plot, highlighting data clustering and potential outliers.

# %%
df[temperature_columns[1:]].plot(kind="area", stacked=True, alpha=0.4, figsize=(12, 6))
plt.title("Stacked Area Plot of Seasonal Temperatures")
plt.xlabel("Year")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot illustrates seasonal temperature trends over time using a stacked area chart, highlighting cumulative variations.

# %%
plt.figure(figsize=(12, 5))
sns.pointplot(x=df["DECADE"], y=df["ANNUAL"], capsize=0.2, color="purple")
plt.title("Point Plot of Annual Temperature by Decade")
plt.xlabel("Decade")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# The plot visualizes decadal average temperatures with variability, highlighting trends and potential climate changes over time.

# %%
plt.hist(df["ANNUAL"], bins=15, color="orange", edgecolor="black")
plt.title("Histogram of Annual Temperatures")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The plot displays the distribution of annual temperatures, highlighting frequency variations and potential climate trends.

# %% [markdown]
# Analysis of Annual and Seasonal Temperature Trends with Data Cleaning
#
# The dataset contains annual and seasonal temperature measurements across various years. We have performed data cleaning and used different visualizations to understand temperature trends and patterns.
#
# Data Cleaning Process
#
# Before analyzing the data, we applied the following cleaning steps to ensure accuracy and consistency:
#
# 1. Handling Missing Values:
#    - Converted all temperature columns to numeric format and replaced non-numeric values with NaN.
#    - Used the mean values of respective columns to fill in missing temperature data.
#    - For missing YEAR values, we replaced them with the mean year value.
#
# 2. Data Type Conversion:
#    - Converted YEAR and temperature columns (ANNUAL, JAN-FEB, MAR-MAY, JUN-SEP, OCT-DEC) to integer format for consistency.
#
# 3. Removing Duplicates:
#    - Checked for duplicate rows and removed them if any were found.
#
# 4. Standardizing Column Names:
#    - Ensured all column names were uniform and properly formatted for easier processing.
#
# Temperature Trend Analysis
#
# 1. Annual Temperature Trend
# - A line chart visualizes the trend of annual average temperatures over time.
# - Helps identify whether global temperatures are rising, stable, or declining.
#
# 2. Decadal Temperature Changes
# - Instead of analyzing each year separately, we group data by decades.
# - This smoothens fluctuations and highlights long-term climate shifts.
#
# 3. Seasonal Temperature Variations
# - Line charts for different seasons: Winter (Jan-Feb), Summer (Mar-May), Monsoon (Jun-Sep), and Post-Monsoon (Oct-Dec).
# - Helps compare how temperatures in each season have changed over time.
#
# 4. Yearly Temperature Distribution (Boxplot)
# - A boxplot shows temperature variations across different decades.
# - Useful for detecting outliers and overall distribution changes.
#
# 5. Histogram of Temperature Ranges
# - A histogram displays the frequency of temperature values.
# - Helps identify common temperature ranges in the dataset.
#
# 6. Scatter Plot of Temperature vs Year
# - Each point represents a year's temperature.
# - Helps identify clusters or anomalies in temperature trends.
#
# 7. Rolling Average Trend
# - A smoothed line (rolling average) reduces short-term fluctuations.
# - Makes long-term warming or cooling trends clearer.
#
# 8. Comparing Decades with Bar Charts
# - A bar chart compares average temperatures across decades.
# - Helps identify which decade was the warmest or coldest.
#
# 9. Correlation Heatmap
# - A heatmap shows relationships between different seasonal temperatures.
# - Helps determine if warming is consistent across all seasons.
#
# 10. Temperature Anomalies Over Time
# - A deviation chart shows how each year's temperature compares to a long-teights into climate trends and the impact of global warming over time.
